# %%
import numpy as np
import pandas as pd
df =pd.read_csv('datasets/titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
##Plaot how many passnegers were children, youth, middle age and old
import matplotlib.pyplot as plt


df['Age'].hist(bins=16)
plt.show()

# %%
#By Sex
df[(df["Sex"] == "female")].Age.hist(bins = 16)
df[(df["Sex"] == "male")].Age.hist(bins = 16)
plt.show()

# %%
# HOw many age values are empty(null)
df['Age'].isna().sum()
# Out:
# 177

# %%
#Add columb

def gender(Sex):
    if Sex == "Male":
        return 1
    else:
        return 0
    
df['Gender']
for each row:
    Gender = gender(Sex)
# Out:
#   File "<ipython-input-7-681a06c74397>", line 10
#     for each row:
#                ^
# SyntaxError: invalid syntax

# %%
#GENDER
df['Gender'] = df['Sex'].map({'female':0, 'male':1}).astype(int)
df
# .map will take an imput and give an output kinda like if in excel .astype(int) will make sure it is
# an intiger.
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
#Show age range
df['Age'].plot.box()

# %%
#List all ages that are not null

#loop over ages, if the age is unique append it to list. 
type(df["Age"].dropna().values

# .dropna() will drop the null values from the list
# .values will return
# Out:
#   File "<ipython-input-10-b7ae38f21b0f>", line 7
#     # .values will return
#                           ^
# SyntaxError: unexpected EOF while parsing

# %%
df[df['Embarked'] == 'C'].head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 9            10         1       2
# 19           20         1       3
# 26           27         0       3
# 30           31         0       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 19                            Masselmani, Mrs. Fatima  female   NaN      0
# 26                            Emir, Mr. Farred Chehab    male   NaN      0
# 30                           Uruchurtu, Don. Manuel E    male  40.0      0
#
#     Parch    Ticket     Fare Cabin Embarked  Gender
# 1       0  PC 17599  71.2833   C85        C       0
# 9       0    237736  30.0708   NaN        C       0
# 19      0      2649   7.2250   NaN        C       0
# 26      0      2631   7.2250   NaN        C       1
# ...

# %%
# plot age range for those who embarked at section C
df[(df["Embarked"] == "C")].Age.hist(bins = 16)

# %%
#by class
df[(df["Embarked"] == "S")].Pclass.hist(bins = 3)
df[(df["Embarked"] == "Q")].Pclass.hist(bins = 3)
df[(df["Embarked"] == "C")].Pclass.hist(bins = 3)

# %%
# HOw many unique values does Embarked have
df['Embarked'].describe()
# Out:
# count     889
# unique      3
# top         S
# freq      644
# Name: Embarked, dtype: object

# %%
#Get unique values of embarked
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
#count deefferend embarked values
df['Embarked'].nunique()
# Out:
# 3

# %%
df['Embarked'].value_counts().plot(kind="bar")

# %%
df['Embarked'].value_counts().plot(kind="barh").invert_yaxis()

# %%
#Another way to do the count and plot it
import seaborn as sns

#Bar chart example
sns.countplot(x="Embarked", palette="spring", data=df)

# %%
#How many passengers were what age at section "C"
df[df['Embarked']=='C'].groupby('Sex')['Age'].plot(bins=16, kind = 'hist', legend=True, alpha = .7)
# Out:
# Sex
# female    AxesSubplot(0.125,0.125;0.775x0.755)
# male      AxesSubplot(0.125,0.125;0.775x0.755)
# Name: Age, dtype: object

# %%
#What is the average age based on sex for those who have embarked on section "C"

df[df['Embarked']=='C'].groupby('Sex')["Age"].mean()

# .agg will agrigate
df[df['Embarked']=='C'].groupby('Sex')["Age"].agg(np.mean)
# Out:
# Sex
# female    28.344262
# male      32.998841
# Name: Age, dtype: float64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Gender
# 0      0         A/5 21171   7.2500   NaN        S       1
# 1      0          PC 17599  71.2833   C85        C       0
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0
# 3      0            113803  53.1000  C123        S       0
# ...

# %%
# Create a scatterplot for age and fair paid
sns.regplot(x="Age", y="Fare", fit_reg= False, data=df)

# %%
df.plot.scatter(x= "Age", y="Fare")

# %%
#% of sex survied by pasenger class Use Hue arg to split data
sns.barplot(x="Pclass", y="Survived", hue="Sex", data=df)

# %%
#Bar plots are orgnized into buckets of data so that we dont get a bunch of bars

# %%
# How many male to female by classe hue groups by ...field...
sns.countplot(x="Pclass", hue="Sex", data=df)

# %%
# Verify data by crunching #bers
df[(df['Sex']=='female')&(df['Pclass']==1)]['Survived'].value_counts()
# Out:
# 1    91
# 0     3
# Name: Survived, dtype: int64

# %%
# stack plot of count based on sex for different passenger clsss
df.groupby(['Sex'])['Pclass'].value_counts().unstack().plot(kind='bar', stacked=True)

# %%
df.groupby(['Sex','Survived'])['Pclass'].value_counts().unstack().plot(kind="bar", stacked=True)

# %%
# sometimes its hard to read values from plot
pd.crosstab(df['Sex'], df['Pclass'])
# Out:
# Pclass    1    2    3
# Sex
# female   94   76  144
# male    122  108  347

# %%
pd.crosstab(df['Sex'], df['Survived'])
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      468  109

# %%
pd.crosstab(df['Sex'], df['Embarked'])
# Out:
# Embarked   C   Q    S
# Sex
# female    73  36  203
# male      95  41  441

# %%
#How to reporesent of the crosstab in % and graphically
sns.heatmap(pd.crosstab(df['Sex'], df['Embarked'], normalize='index'), cmap="YlGnBu", annot=True)

# %%
# Combine Datasets in Pandas
