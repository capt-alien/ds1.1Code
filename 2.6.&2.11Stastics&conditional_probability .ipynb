# %%
# Some Handy Dandy Import Statements to Start Off Our Handy Dandy Little Tutorial
from scipy import stats
import math
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# 1) Descriptive stastics


# Mean average

# %%
data = np.array([1, 3, 5, 2, 3, 7, 8, 4, 10, 0, 6, 7, 3, 0, 3, 0, 5, 7, 10, 1, 4, 9, 3])

# TODO: Complete this function by having the function return the average value of our dataset.
def compute_mean(dataset):
    return mean(
        dataset.np.mean()

compute_mean(data)
# Out:
#   File "<ipython-input-5-0a47bb6d9a8d>", line 8
#     compute_mean(data)
#                ^
# SyntaxError: invalid syntax

# %%
data = np.array([1, 3, 5, 2, 3, 7, 8, 4, 10, 0, 6, 7, 3, 0, 3, 0, 5, 7, 10, 1, 4, 9, 3])

# TODO: Complete this function by having the function return the exact true median value of our dataset.
# HINT: Consider using DataFrame slicing to help with identifying the correct median value(s).
def compute_median(dataset):
    """ Main function that determines the median value across our data. """
    count = len(dataset)
    dataset = sorted(dataset)
    
    if count < 1:
        # TODO: Complete this if-statement
        return dataset[count]
    if count % 2 == 1:
        # TODO: Complete this if-statement
        return (dataset[count //2] + dataset[(count + 1)//2])/2
    else:
        # TODO: Complete this if-else statement
        returndataset[count //2]
    
compute_median(data)
# Out:
# 4.0

# %%
# NOTE: Tricker than it looks!
data = np.array([1, 3, 5, 2, 3, 7, 8, 4, 10, 0, 6, 7, 3, 0, 3, 0, 5, 7, 10, 1, 4, 9, 3])

# TODO: Complete this function by having the function return the relative mode across our dataset.
# HINT: Remember histograms and tokenization from CS 1.2? How many they help you here? 
def compute_mode(dataset):
    """ Main function that determines the mode value across our data. """
    num_counter= {}
    for num in dataset:
        if num not in (num_counter):
            num_counter[num] = 0
        num_counter[num] += 1
#         return key with max value
        winer = max(sorted(num_counter.items(), key =lambda kv:kv[1])
                    
    return winer

compute_mode(data)
# Out:
#   File "<ipython-input-7-6c553acd6d14>", line 16
#     return winer
#          ^
# SyntaxError: invalid syntax

# %%
df = pd.read_csv('datasets/titanic.csv')

# %%
import matplotlib.pyplot as plt

df['Fare'].hist(bins=16)
plt.show()

# %%
#How many passengers paied less then mean/
#Or total # of people that aid the mean

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
m_fare=df['Fare'].mean()
ls_fare = df['Fare'].dropna().values
numbers_below_mean = df[df['Fare']<= np.median(ls_fare)]
numbers_below_mean
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# 8              9         1       3
# 12            13         0       3
# 14            15         0       3
# 17            18         1       2
# 19            20         1       3
# 21            22         1       2
# 22            23         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 32            33         1       3
# 33            34         0       2
# 36            37         1       3
# 37            38         0       3
# 39            40         1       3
# 40            41         0       3
# 42            43         0       3
# 44            45         1       3
# 45            46         0       3
# 47            48         1       3
# 51            52         0       3
# ...

# %%
# Variance range and %

# %%
data = np.array([1, 3, 5, 2, 3, 7, 8, 4, 10, 0, 6, 7, 3, 0, 3, 0, 5, 7, 10, 1, 4, 9, 3])

# TODO: Complete this function by having the function return the effective range of values across our data.
def compute_range(dataset):
    """ Main function that determines the range of values across our data. """
    top = dataset.max()
    bottom = dataset.min()
    return (bottom, top)

compute_range(data)
# Out:
# (0, 10)

# %%
# Variance = SD^2

data = np.array([1, 3, 5, 2, 3, 7, 8, 4, 10, 0, 6, 7, 3, 0, 3, 0, 5, 7, 10, 1, 4, 9, 3])

# TODO: Complete this function by having the function return the standard deviation of our data.
# NOTE: Since we need the true mean across our data, let's use our previously written function!
def compute_standard_deviation(dataset):
    """ Main function that approximates the standard deviation of our data. """
    true_mean = compute_mean(dataset)
    sub_value = 0
    for value in data:
        sub_value += (value - sub_value)**2
    AB = (sub_value/dataset.len())    
        
    # TODO: Complete these calculations step-by-step to correct the standard deviation calculation.
    sum_diffs_squared = int()
    variance = int()
    
    return math.sqrt(AB)

compute_standard_deviation(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-acd0d4235d88> in <module>
#      19     return math.sqrt(AB)
#      20
# ---> 21 compute_standard_deviation(data)
#      22
#
# <ipython-input-15-acd0d4235d88> in compute_standard_deviation(dataset)
#       7 def compute_standard_deviation(dataset):
#       8     """ Main function that approximates the standard deviation of our data. """
# ----> 9     true_mean = compute_mean(dataset)
#      10     sub_value = 0
#      11     for value in data:
#
# NameError: name 'compute_mean' is not defined

# %%
##Compute ercentile for fare
np.percentile(ls_fare, 75)

# %%
numbers_below_precentil = df[df['Fare'] <= np.percentile(ls_fare,75)]

# %%
# REVIEW
# measures of central tendencies:
#     mean  -------> average
#     median ------>  center of the range
#     mode --------> most occuring instance

# %%
# ******************
# Notes: 2.11.19
# ******************
# X is outcome of a coin toss. 

# P(x=h)=H occurances/# of trials

# *****
# Dependant events . (mutually exclusive if one thing happens the other thing cannot
# 


# 2/5 balls are blue in first trial
# given the second trial created a pool of balls that are 1/4 blue what
# is the probablility of the ball being blue--

# (1/4)*(2/5)+ (1/2)*3/5 = 40%

# %%
# Conditional probabiliby 
# P(B|A) = (P(A&B)/P(A))

# %%
import seaborn as sns

sns.distplot(df['Age'].dropna(), hist_kws=dict(cumulative=True), kde_kws= dict(cumulative=True))
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# https://github.com/Make-School-Courses/DS-1.1-Data-Analysis/blob/master/Lessons/AppliedProbabilitytodataframe.md

# %%
# tennis
import pandas as pd
# Outlook	Temp.	Humidity	Wind	Decision
df = pd.read_csv('datasets/tennis.txt', delimiter="\t", header=None, names=['Outlook', 'Temp', 'Humidity', 'Wind', 'Decision'])
df[df['Wind'] == 'Weak']
df[df['Wind'] == 'Weak']['Decision']
def conditional_prob(c1, c2, condition):
    
    df_new = df[df[c1] == condition][c2]
    s = df_new.unique()
    population_size = len(df_new)
    pr = {}
    
    for i in s:
        pr[i] = len(df[(df[c1] == condition) & (df[c2]== i)]) / population_size

    return pr

print(conditional_prob('Wind', 'Decision', 'Weak'))
print(conditional_prob('Wind', 'Decision', 'Strong'))
# Out:
# {'No': 0.25, 'Yes': 0.75}
# {'No': 0.5, 'Yes': 0.5}

# %%
df
# Out:
#      Outlook  Temp Humidity    Wind Decision
# 1      Sunny   Hot     High    Weak       No
# 2      Sunny   Hot     High  Strong       No
# 3   Overcast   Hot     High    Weak      Yes
# 4       Rain  Mild     High    Weak      Yes
# 5       Rain  Cool   Normal    Weak      Yes
# 6       Rain  Cool   Normal  Strong       No
# 7   Overcast  Cool   Normal  Strong      Yes
# 8      Sunny  Mild     High    Weak       No
# 9      Sunny  Cool   Normal    Weak      Yes
# 10      Rain  Mild   Normal    Weak      Yes
# 11     Sunny  Mild   Normal  Strong      Yes
# 12  Overcast  Mild     High  Strong      Yes
# 13  Overcast   Hot   Normal    Weak      Yes
# 14      Rain  Mild     High  Strong       No

# %%
# Out:
#      Outlook  Temp Humidity    Wind Decision
# 1      Sunny   Hot     High    Weak       No
# 2      Sunny   Hot     High  Strong       No
# 3   Overcast   Hot     High    Weak      Yes
# 4       Rain  Mild     High    Weak      Yes
# 5       Rain  Cool   Normal    Weak      Yes
# 6       Rain  Cool   Normal  Strong       No
# 7   Overcast  Cool   Normal  Strong      Yes
# 8      Sunny  Mild     High    Weak       No
# 9      Sunny  Cool   Normal    Weak      Yes
# 10      Rain  Mild   Normal    Weak      Yes
# 11     Sunny  Mild   Normal  Strong      Yes
# 12  Overcast  Mild     High  Strong      Yes
# 13  Overcast   Hot   Normal    Weak      Yes
# 14      Rain  Mild     High  Strong       No

# %%
# Prove 6 sigma
import scipy.stats as st

print(st.norm.cdf(1)- st.norm.cdf(-1))
# Out:
# 0.6826894921370859

# %%
##Figure out what he means by pdf and cdf
# Cumulative distribution function
# PDF is Probability density function

# %%
print(st.norm.cdf(2)- st.norm.cdf(-2))
# Out:
# 0.9544997361036416

# %%
print(st.norm.cdf(3)- st.norm.cdf(-3))
# Out:
# 0.9973002039367398

# %%
print(1-(st.norm.cdf(1)))
# Out:
# 0.15865525393145707

# %%
print(1-(st.norm.cdf(.5)))
# Out:
# 0.3085375387259869

# %%
from scipy.stats import norm

norm.sf(70, loc=65, scale=10)
# Out:
# 0.3085375387259869
